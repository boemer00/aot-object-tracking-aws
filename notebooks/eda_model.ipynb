# %%
import os
import sys
import random
import json
import cv2
import numpy as np
from random import randrange, choice

import matplotlib.pyplot as plt
from IPython.display import display

random.seed(0)

# %%
# !aws s3 ls --no-sign-request s3://airborne-obj-detection-challenge-training/
# Out:
#                            PRE part1/
#                            PRE part2/
#                            PRE part3/

# %%
# !aws s3 cp --recursive --no-sign-request s3://airborne-obj-detection-challenge-training/ /Users/renatoboemer/code/developer/aot-object-tracking-aws/raw_data/
# Out:
# download: s3://airborne-obj-detection-challenge-training/part1/ImageSets/valid_encounters_maxRange700_maxGap3_minEncLen30.csv to ../raw_data/part1/ImageSets/valid_encounters_maxRange700_maxGap3_minEncLen30.csv
# download: s3://airborne-obj-detection-challenge-training/part1/Images/0001ba865c8e410e88609541b8f55ffc/15549773494832603520001ba865c8e410e88609541b8f55ffc.png to ../raw_data/part1/Images/0001ba865c8e410e88609541b8f55ffc/15549773494832603520001ba865c8e410e88609541b8f55ffc.png
# download: s3://airborne-obj-detection-challenge-training/part1/Images/0001ba865c8e410e88609541b8f55ffc/15549773495887103050001ba865c8e410e88609541b8f55ffc.png to ../raw_data/part1/Images/0001ba865c8e410e88609541b8f55ffc/15549773495887103050001ba865c8e410e88609541b8f55ffc.png
# ...
